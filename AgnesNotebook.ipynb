# %%
import pandas as pd
import numpy as np
import matplotlib as mp
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

df = pd.read_csv('happy_score')

# %%
df
# Out:
#                 country  adjusted_satisfaction  avg_satisfaction  \
# 0               Armenia                   37.0               4.9
# 1                Angola                   26.0               4.3
# 2             Argentina                   60.0               7.1
# 3               Austria                   59.0               7.2
# 4             Australia                   65.0               7.6
# 5            Azerbaijan                   46.0               5.8
# 6            Bangladesh                   43.0               5.3
# 7               Belgium                   63.0               7.2
# 8          Burkina Faso                   37.0               4.4
# 9              Bulgaria                   34.0               4.6
# 10              Burundi                   25.0               2.9
# 11                Benin                   20.0               3.0
# 12              Bolivia                   53.0               6.3
# ...

# %%
df1 = df['adjusted_satisfaction']
df2 = df['happyScore']

# %%
happy_happy = np.column_stack((df1,df2))
km_res = KMeans(n_clusters=10).fit(happy_happy)

# %%
km_res.cluster_centers_
clusters = km_res.cluster_centers_

# %%
clusters
# Out:
# array([[70.55555556,  7.42455556],
#        [34.09090909,  4.24981818],
#        [54.71428571,  5.82909524],
#        [44.        ,  5.00052632],
#        [20.33333333,  3.32      ],
#        [38.84615385,  4.22553846],
#        [65.        ,  6.962     ],
#        [48.30769231,  5.36315385],
#        [27.        ,  3.966     ],
#        [59.72727273,  6.51190909]])

# %%
df1.max()
# Out:
# 74.0

# %%
plt.scatter(df['adjusted_satisfaction'], df['happyScore'],)

plt.scatter(clusters[:,0], clusters [:,1], s =10)
plt.text(df.iloc[0]['adjusted_satisfaction'],
        df.iloc[0]['happyScore'],
        df.iloc[0]['country'])
plt.text(df.iloc[-1]['adjusted_satisfaction'],
        df.iloc[-1]['happyScore'],
        df.iloc[-1]['country'])
plt.xlabel('adjusted_satisfaction')
plt.ylabel('Happy Score')
# Out:
# Text(0,0.5,'Happy Score')
