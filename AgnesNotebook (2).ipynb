# %%
import pandas as pd
import numpy as np
import matplotlib as mp
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

df = pd.read_csv('business_data.csv')

# %%
df
# Out:
#             V1        V2
# 0     3.621600   8.66610
# 1     4.545900   8.16740
# 2     3.866000  -2.63830
# 3     3.456600   9.52280
# 4     0.329240  -4.45520
# 5     4.368400   9.67180
# 6     3.591200   3.01290
# 7     2.092200  -6.81000
# 8     3.203200   5.75880
# 9     1.535600   9.17720
# 10    1.224700   8.77790
# 11    3.989900  -2.70660
# 12    1.899300   7.66250
# 13   -1.576800  10.84300
# 14    3.404000   8.72610
# 15    4.676500  -3.38950
# 16    2.671900   3.06460
# 17    0.803550   2.84730
# 18    1.447900  -4.87940
# 19    5.242300  11.02720
# 20    5.786700   7.89020
# 21    0.329200  -4.45520
# 22    3.936200  10.16220
# 23    0.935840   8.88550
# 24    4.433800   9.88700
# 25    0.705700  -5.49810
# 26    1.143200  -3.74130
# 27   -0.382140   8.39090
# 28    6.563300   9.81870
# 29    4.890600  -3.35840
# ...        ...       ...
# 1342 -1.747900  -5.82300
# 1343 -0.959230  -6.71280
# 1344  1.345100   0.23589
# 1345  2.227900   4.09510
# 1346  1.257200   4.87310
# ...

# %%
df.describe()

# here are the statistical Values
# Out:
#                 V1           V2
# count  1372.000000  1372.000000
# mean      0.433735     1.922353
# std       2.842763     5.869047
# min      -7.042100   -13.773100
# 25%      -1.773000    -1.708200
# 50%       0.496180     2.319650
# 75%       2.821475     6.814625
# max       6.824800    12.951600

# %%
# Split the columns into two dataframes, or whatever
df3 = df['V1']
df4 = df['V2']

# %%
# Now.. cluster this ?
wtdh = np.column_stack((df3,df4))
km_res = KMeans(n_clusters=10).fit(wtdh)
km_res.cluster_centers_
clusters = km_res.cluster_centers_

km_res1 = KMeans(n_clusters=3).fit(wtdh)
km_res1.cluster_centers_
clusters1 = km_res1.cluster_centers_


km_res2 = KMeans(n_clusters=2).fit(wtdh)
km_res2.cluster_centers_
clusters2 = km_res2.cluster_centers_

# %%
# Plotted these.. random values Lets just practice visualizing this data 
from matplotlib.pyplot import figure

figure(figsize=(10, 10), dpi=80)
plt.scatter(df['V1'], df['V2'], )
plt.scatter(clusters[:,0], clusters [:,1], s =25)
plt.scatter(clusters1[:,0],clusters1 [:,1], s =25)
plt.scatter(clusters2[:,0],clusters2 [:,1], s =25)
plt.xlabel('V1')
plt.ylabel('V2')
# Out:
# Text(0,0.5,'V2')

# %%
# play with some alpha values
figure(figsize=(10, 10), dpi=80)
plt.scatter(df['V1'], df['V2'], )
plt.scatter(clusters[:,0], clusters [:,1], s =1000, alpha =0.4)

plt.xlabel('V1')
plt.ylabel('V2')
# Out:
# Text(0,0.5,'V2')

# %%
happy_happy = np.column_stack((df3,df4))
km_res = KMeans(n_clusters=2).fit(happy_happy)

# %%
km_res.cluster_centers_
clusters = km_res.cluster_centers_

# %%
clusters
# Out:
# array([[ 0.86646672,  6.04670363],
#        [-0.14152575, -3.5604422 ]])

# %%
from sklearn.cluster import KMeans

data = list(zip(df3, df4))
inertias = []

for i in range(1,11):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(data)
    inertias.append(kmeans.inertia_)

plt.plot(range(1,11), inertias, marker='o')
plt.title('Elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %%
kmeans = KMeans(n_clusters=2)
kmeans.fit(data)

plt.scatter(df3, df4, c=kmeans.labels_)
plt.scatter(clusters2[:,0],clusters2 [:,1], s =200)
plt.show()

# %%
# From the very basic information I have been provided I can see that , yes This data set it suitable for K means clustering.

# %%
np.var(df3)
# Out:
# 8.075408962045568

# %%
np.var(df4)
# Out:
# 34.42060347594198

# %%
stacks = np.column_stack((df3,df4))

# %%
np.var(clusters)
# Out:
# 11.858053088093023
