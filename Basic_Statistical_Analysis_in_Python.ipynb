# %% [markdown]
# <a href="https://colab.research.google.com/github/oohtmeel1/Python-Project/blob/main/Basic_Statistical_Analysis_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# World Bank Science and Technology data analysys

# %%
print("Hello World")
# Out:
# Hello World

# %%
import pandas as pd

# %%
st_data_2018 = pd.read_csv("/content/science_tech_2018.csv")
st_data_2018.head()
# Out:
#      Country Name  High-technology exports (% of manufactured exports)  \
# 0     Afghanistan                                                NaN
# 1         Albania                                           0.049514
# 2         Algeria                                                NaN
# 3  American Samoa                                                NaN
# 4         Andorra                                          28.460560
#
#    High-technology exports (current US$)  Trademark applications, total  \
# 0                                    NaN                            NaN
# 1                               591717.0                         3713.0
# 2                                    NaN                         9490.0
# 3                                    NaN                            NaN
# 4                             33913480.0                         1180.0
#
#    Trademark applications, direct resident  \
# 0                                      NaN
# ...

# %%
st_data_2018.shape
# Out:
# (219, 10)

# %%
st_data_2018.size
# Out:
# 2190

# %%
st_data_2018.columns
# Out:
# Index(['Country Name', 'High-technology exports (% of manufactured exports)',
#        'High-technology exports (current US$)',
#        'Trademark applications, total',
#        'Trademark applications, direct resident',
#        'Trademark applications, direct nonresident',
#        'Patent applications, residents', 'Patent applications, nonresidents',
#        'Scientific and technical journal articles',
#        'Research and development expenditure (% of GDP)'],
#       dtype='object')

# %%
st_data_2009 = pd.read_csv("/content/science_tech_2009.csv")
st_data_2009.head()
# Out:
#      Country Name  High-technology exports (% of manufactured exports)  \
# 0     Afghanistan                                                NaN
# 1         Albania                                           1.328024
# 2         Algeria                                           0.653887
# 3  American Samoa                                                NaN
# 4         Andorra                                          12.192161
#
#    High-technology exports (current US$)  Trademark applications, total  \
# 0                                    NaN                            NaN
# 1                             10128935.0                         3456.0
# 2                              4616076.0                         5345.0
# 3                                    NaN                            NaN
# 4                             10402350.0                          785.0
#
#    Trademark applications, direct resident  \
# 0                                      NaN
# ...

# %% [markdown]
# ##New Section
#
# ####Cleaning The Data

# %%
st_data_2018.isna().sum()
# Out:
# Country Name                                             0
# High-technology exports (% of manufactured exports)     87
# High-technology exports (current US$)                   88
# Trademark applications, total                           86
# Trademark applications, direct resident                 91
# Trademark applications, direct nonresident              90
# Patent applications, residents                         101
# Patent applications, nonresidents                      100
# Scientific and technical journal articles               20
# Research and development expenditure (% of GDP)        146
# dtype: int64

# %%
st_data_2018_clean = st_data_2018.dropna()

# %%
st_data_2018_clean.shape
# Out:
# (51, 10)

# %%
st_data_2009_clean = st_data_2009.dropna()

# %%
st_data_2009.shape
# Out:
# (219, 10)

# %% [markdown]
# ##Exploratory Data Analysis
#
# ###Cleaning Data More

# %%
pd.set_option('display.float_format', lambda x: '%.3f' %x)
st_data_2018_clean.describe()
# Out:
#        High-technology exports (% of manufactured exports)  \
# count                                             51.000
# mean                                              11.874
# std                                                7.902
# min                                                0.042
# 25%                                                5.337
# 50%                                               10.368
# 75%                                               17.103
# max                                               36.347
#
#        High-technology exports (current US$)  Trademark applications, total  \
# count                                 51.000                         51.000
# mean                         25697867097.059                      44515.294
# std                          48690230335.519                      85393.786
# min                               115051.000                       1974.000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.boxplot(x= st_data_2018_clean['High-technology exports (% of manufactured exports)'])

# %%
sns.boxplot(x= st_data_2009_clean['High-technology exports (% of manufactured exports)'])

# %% [markdown]
# ## Creating for loops to look over many columns
# ### Outliers

# %%
columns = st_data_2018_clean.columns
# An array is returned
columns
# Out:
# Index(['Country Name', 'High-technology exports (% of manufactured exports)',
#        'High-technology exports (current US$)',
#        'Trademark applications, total',
#        'Trademark applications, direct resident',
#        'Trademark applications, direct nonresident',
#        'Patent applications, residents', 'Patent applications, nonresidents',
#        'Scientific and technical journal articles',
#        'Research and development expenditure (% of GDP)'],
#       dtype='object')

# %%
for i in range(1,len(columns)):
  fig = plt.figure(figsize=(10,5))
  sns.boxplot(x= st_data_2018_clean[columns[i]])

# %%
articles_max = st_data_2018_clean['Scientific and technical journal articles'].max()

# %%
st_data_2018_clean[st_data_2018['Scientific and technical journal articles']==articles_max]
# Out:
# <ipython-input-58-d1637cb6c449>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_data_2018_clean[st_data_2018['Scientific and technical journal articles']==articles_max]
#       Country Name  High-technology exports (% of manufactured exports)  \
# 207  United States                                             18.896
#
#      High-technology exports (current US$)  Trademark applications, total  \
# 207                       156365524736.000                     464786.000
#
#      Trademark applications, direct resident  \
# 207                               342150.000
#
#      Trademark applications, direct nonresident  \
# 207                                  122636.000
#
#      Patent applications, residents  Patent applications, nonresidents  \
# 207                      285095.000                         312046.000
#
#      Scientific and technical journal articles  \
# 207                                 422807.710
#
# ...

# %% [markdown]
# To sort out all of the values that are too high: set the value to be > 60000 instead of just == max

# %%
st_data_2018_clean[st_data_2018['Scientific and technical journal articles'] > 60000]
# Out:
# <ipython-input-59-1d623765275c>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_data_2018_clean[st_data_2018['Scientific and technical journal articles'] > 60000]
#            Country Name  High-technology exports (% of manufactured exports)  \
# 68               France                                             25.920
# 73              Germany                                             15.778
# 89                India                                              9.008
# 96                Italy                                              7.505
# 98                Japan                                             17.268
# 104         Korea, Rep.                                             36.347
# 161  Russian Federation                                             10.963
# 206      United Kingdom                                             22.643
# 207       United States                                             18.896
#
# ...

# %% [markdown]
# ## Exploring numeric relationships
#
# ### Correlations

# %%
st_data_2018_clean.corr(method = 'pearson').style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_154d8_row0_col0, #T_154d8_row1_col1, #T_154d8_row2_col2, #T_154d8_row3_col3, #T_154d8_row4_col4, #T_154d8_row5_col5, #T_154d8_row6_col6, #T_154d8_row7_col7, #T_154d8_row8_col8 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_154d8_row0_col1 {
#   background-color: #482374;
#   color: #f1f1f1;
# }
# #T_154d8_row0_col2 {
#   background-color: #48186a;
#   color: #f1f1f1;
# }
# #T_154d8_row0_col3, #T_154d8_row8_col1, #T_154d8_row8_col6 {
#   background-color: #481769;
#   color: #f1f1f1;
# }
# #T_154d8_row0_col4, #T_154d8_row8_col7 {
#   background-color: #481b6d;
#   color: #f1f1f1;
# }
# #T_154d8_row0_col5, #T_154d8_row0_col6, #T_154d8_row0_col7, #T_154d8_row4_col8, #T_154d8_row6_col0, #T_154d8_row6_col1, #T_154d8_row8_col2, #T_154d8_row8_col3, #T_154d8_row8_col4 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_154d8_row0_col8 {
#   background-color: #218e8d;
#   color: #f1f1f1;
# }
# #T_154d8_row1_col0 {
# ...

# %%
st_data_2018_clean.corr(method = 'spearman').style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_ea0cd_row0_col0, #T_ea0cd_row1_col1, #T_ea0cd_row2_col2, #T_ea0cd_row3_col3, #T_ea0cd_row4_col4, #T_ea0cd_row5_col5, #T_ea0cd_row6_col6, #T_ea0cd_row7_col7, #T_ea0cd_row8_col8 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_ea0cd_row0_col1, #T_ea0cd_row8_col1 {
#   background-color: #1f9e89;
#   color: #f1f1f1;
# }
# #T_ea0cd_row0_col2 {
#   background-color: #481668;
#   color: #f1f1f1;
# }
# #T_ea0cd_row0_col3 {
#   background-color: #471063;
#   color: #f1f1f1;
# }
# #T_ea0cd_row0_col4 {
#   background-color: #463480;
#   color: #f1f1f1;
# }
# #T_ea0cd_row0_col5, #T_ea0cd_row0_col6, #T_ea0cd_row0_col7, #T_ea0cd_row4_col0, #T_ea0cd_row4_col1, #T_ea0cd_row4_col8, #T_ea0cd_row8_col2, #T_ea0cd_row8_col3, #T_ea0cd_row8_col4 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_ea0cd_row0_col8, #T_ea0cd_row7_col6 {
#   background-color: #25ac82;
#   color: #f1f1f1;
# }
# #T_ea0cd_row1_col0, #T_ea0cd_row2_col5 {
# ...

# %%
st_data_2009_clean.corr(method = 'pearson').style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_133a1_row0_col0, #T_133a1_row1_col1, #T_133a1_row2_col2, #T_133a1_row2_col3, #T_133a1_row3_col2, #T_133a1_row3_col3, #T_133a1_row4_col4, #T_133a1_row5_col5, #T_133a1_row6_col6, #T_133a1_row7_col7, #T_133a1_row8_col8 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_133a1_row0_col1 {
#   background-color: #46307e;
#   color: #f1f1f1;
# }
# #T_133a1_row0_col2 {
#   background-color: #482173;
#   color: #f1f1f1;
# }
# #T_133a1_row0_col3 {
#   background-color: #482071;
#   color: #f1f1f1;
# }
# #T_133a1_row0_col4 {
#   background-color: #472f7d;
#   color: #f1f1f1;
# }
# #T_133a1_row0_col5, #T_133a1_row0_col6, #T_133a1_row0_col7, #T_133a1_row3_col0, #T_133a1_row3_col8, #T_133a1_row8_col1, #T_133a1_row8_col2, #T_133a1_row8_col3, #T_133a1_row8_col4 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_133a1_row0_col8, #T_133a1_row1_col0 {
#   background-color: #34608d;
#   color: #f1f1f1;
# }
# #T_133a1_row1_col2, #T_133a1_row3_col4 {
# ...

# %%
st_data_2009_clean.corr(method = 'spearman').style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_d9c33_row0_col0, #T_d9c33_row1_col1, #T_d9c33_row2_col2, #T_d9c33_row3_col3, #T_d9c33_row4_col4, #T_d9c33_row5_col5, #T_d9c33_row6_col6, #T_d9c33_row7_col7, #T_d9c33_row8_col8 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_d9c33_row0_col1 {
#   background-color: #26828e;
#   color: #f1f1f1;
# }
# #T_d9c33_row0_col2, #T_d9c33_row0_col3, #T_d9c33_row0_col5, #T_d9c33_row0_col7, #T_d9c33_row3_col0, #T_d9c33_row4_col1, #T_d9c33_row4_col8, #T_d9c33_row8_col4, #T_d9c33_row8_col6 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_d9c33_row0_col4 {
#   background-color: #472c7a;
#   color: #f1f1f1;
# }
# #T_d9c33_row0_col6 {
#   background-color: #482374;
#   color: #f1f1f1;
# }
# #T_d9c33_row0_col8 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_d9c33_row1_col0 {
#   background-color: #35b779;
#   color: #f1f1f1;
# }
# #T_d9c33_row1_col2 {
#   background-color: #1e9d89;
#   color: #f1f1f1;
# }
# #T_d9c33_row1_col3 {
# ...

# %%
st_data_2018_clean.plot.scatter(x='Scientific and technical journal articles', y='Patent applications, residents')

# %%
##To deal with the outliers above have to subset the data 

st_data_2018_nonUS = st_data_2018_clean[st_data_2018_clean['Country Name'] != 'United States']

# %%
st_data_2018_nonUS.plot.scatter(x='Scientific and technical journal articles', y='Patent applications, residents')

# %%
# Do it again for 2009 Data

st_data_2009_clean.plot.scatter(x='Scientific and technical journal articles', y='Patent applications, residents')

# %%
st_data_2009_nonUS = st_data_2009_clean[st_data_2009_clean['Country Name'] != 'United States']

# %%
st_data_2009_nonUS.plot.scatter(x='Scientific and technical journal articles', y='Patent applications, residents')

# %% [markdown]
# ## T-Test

# %%
import scipy.stats as stats

# %%
a = st_data_2009_clean['Patent applications, residents']
b = st_data_2018_clean['Patent applications, residents']
stats.ttest_ind(a,b)
# Out:
# Ttest_indResult(statistic=0.17093628150351461, pvalue=0.8646028361752646)

# %%
for i in range(1,len(columns)):
  a = st_data_2009_clean[columns[i]]
  b = st_data_2018_clean[columns[i]]
  print(columns[i])
  statistics, pvalue = stats.ttest_ind(a,b) 
  print("Statistic: %s p-value: %s" %(statistics  ,pvalue))
  if pvalue <0.05: 
    print("significant")
  else:
    print("Not Significatant")
# Out:
# High-technology exports (% of manufactured exports)
# Statistic: 1.5178124850425097 p-value: 0.13206686889029143
# Not Significatant
# High-technology exports (current US$)
# Statistic: 0.12265583290103693 p-value: 0.902614099731734
# Not Significatant
# Trademark applications, total
# Statistic: 0.2704033385824462 p-value: 0.7873807591420726
# Not Significatant
# Trademark applications, direct resident
# Statistic: 0.3877442167941513 p-value: 0.6989902537733603
# Not Significatant
# Trademark applications, direct nonresident
# Statistic: -0.48589263440463604 p-value: 0.628055750890876
# Not Significatant
# Patent applications, residents
# Statistic: 0.17093628150351461 p-value: 0.8646028361752646
# Not Significatant
# Patent applications, nonresidents
# Statistic: -0.044717907923683436 p-value: 0.9644170934929569
# Not Significatant
# Scientific and technical journal articles
# Statistic: -0.006105403997445266 p-value: 0.9951402075104707
# Not Significatant
# ...
